# %% [markdown]
# <a href="https://colab.research.google.com/github/rolleyanne/CSST106-CS4A/blob/main/4A_OYARDO_MP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Load Libraries and Images
#
# ```

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/Mau.png')

# %% [markdown]
# # Apply Scaling

# %%
scaled_img = cv2.resize(img, None, fx=1, fy=1,
interpolation=cv2.INTER_LINEAR)

cv2_imshow(scaled_img)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x2048>

# %% [markdown]
# Apply Rotation

# %%
(h, w) = img.shape[:2]

center = (w // 2, h // 2)

rotation_matrix = cv2.getRotationMatrix2D(center, 35, 1.0)
rotated_img = cv2.warpAffine(img, rotation_matrix, (w, h))

cv2_imshow(rotated_img)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x2048>

# %% [markdown]
# Apply Blurring

# %%
blurred_img = cv2.GaussianBlur(img, (15, 15), 0)

cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x2048>

# %% [markdown]
# Apply Edge Detection

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

edges = cv2.Canny(gray_img, 30, 70)

cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=2048x2048>
